# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ultralytics-8-3-13-py3-none-any/ultralytics-8.3.13-py3-none-any.whl
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/data.yaml
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels.cache
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels/AD27.txt
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels/4H20.txt
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels/6H51.txt
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels/7D35.txt
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels/8H40.txt
# /kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels/10S43.txt
# ...

# %%
# Install ultralytics using pip in Jupyter notebook
# %pip install ultralytics

# from IPython import display
# display.clear_output()
# !rm -rf yolov5_env
# !pip install opencv-python-headless
# import cv2
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.145 🚀 Python-3.7.12 torch-1.11.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5934.2/8062.4 GB disk)

# %%
# Git clone method (for development)
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 44871, done.
# remote: Counting objects: 100% (661/661), done.
# remote: Compressing objects: 100% (469/469), done.
# remote: Total 44871 (delta 418), reused 334 (delta 189), pack-reused 44210 (from 1)
# Receiving objects: 100% (44871/44871), 37.69 MiB | 24.01 MiB/s, done.
# Resolving deltas: 100% (33359/33359), done.
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3 lines of output]
# ...

# %%
import os # operating system

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/images

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/labels

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/images/train

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/images/test

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/labels/train

# %%
mkdir /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/labels/test

# %%
cd /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2
# Out:
# /kaggle/working/ultralytics/the-complete-playing-card-dataset-v2

# %%
from distutils.dir_util import copy_tree

# %%
cd /kaggle
# Out:
# /kaggle

# %%
# Copy train images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/train/images'
toDirectory = '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/10H46.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/5S17.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/JC9.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/2H31.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/5H33.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/4D47.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/6C3.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/6D48.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/10S44.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/images/9H13.jpg',
# ...

# %%
# Copy train images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/images'
toDirectory = '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/KH33.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/4H51.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/JC20.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/4C61.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/QS43.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/AH9.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/7H16.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/2H51.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/7H31.jpg',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/images/KS17.jpg',
# ...

# %%
# Copy train images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/train/labels'
toDirectory = '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/QC35.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/4S29.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/9S6.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/JOKER9.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/8D20.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/KD3.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/8D2.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/4S35.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/6C29.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/train/labels/QH32.txt',
# ...

# %%
# Copy train images from kaggle input directory to kaggle output directory
fromDir = '/kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/valid/labels'
toDirectory = '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels'
copy_tree(fromDir, toDirectory)
# Out:
# ['/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/AD27.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/4H20.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/6H51.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/7D35.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/8H40.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/10S43.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/9S45.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/8D33.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/7C42.txt',
#  '/kaggle/working/ultralytics/the-complete-playing-card-dataset-v2/valid/labels/7C22.txt',
# ...

# %%
# Train YOLOv8n on COCO128 for 64 epochs
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/input/the-complete-playing-card-dataset-v2/the-complete-playing-card-dataset-v2/data.yaml epochs=64 imgsz=640 batch=8 cache=/kaggle/working/
# Out:
# New https://pypi.org/project/ultralytics/8.3.13 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.145 🚀 Python-3.7.12 torch-1.11.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
# !ls -la runs/detect/
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Oct 15 19:39 .
# drwxr-xr-x 3 root root 4096 Oct 15 19:32 ..
# drwxr-xr-x 3 root root 4096 Oct 15 19:32 train
# drwxr-xr-x 3 root root 4096 Oct 15 21:32 train2

# %%
cd runs/detect/train2/
# Out:
# /kaggle/runs/detect/train2

# %%
# !zip -r train2_results.zip "runs/detect/train2/"
# Out:
# 	zip warning: name not matched: runs/detect/train2/
#
# zip error: Nothing to do! (try: zip -r train2_results.zip . -i runs/detect/train2/)

# %%
# !pwd
# Out:
# /kaggle/runs/detect/train2

# %%
# !zip -r train2_results.zip ./
# Out:
# updating: val_batch1_pred.jpg (deflated 18%)
# updating: labels.jpg (deflated 34%)
# updating: labels_correlogram.jpg (deflated 37%)
# updating: events.out.tfevents.1729021162.7fdea52af827.154.0 (deflated 72%)
# updating: train_batch2.jpg (deflated 13%)
# updating: val_batch2_pred.jpg (deflated 21%)
# updating: train_batch14905.jpg (deflated 29%)
# updating: train_batch14906.jpg (deflated 25%)
# updating: val_batch2_labels.jpg (deflated 23%)
# updating: P_curve.png (deflated 9%)
# updating: weights/ (stored 0%)
# updating: weights/best.pt (deflated 9%)
# updating: weights/last.pt (deflated 9%)
# updating: confusion_matrix_normalized.png (deflated 24%)
# updating: F1_curve.png (deflated 9%)
# updating: results.csv (deflated 85%)
# updating: val_batch1_labels.jpg (deflated 19%)
# updating: args.yaml (deflated 52%)
# updating: results.png (deflated 8%)
# updating: R_curve.png (deflated 9%)
# updating: val_batch0_pred.jpg (deflated 20%)
# updating: train_batch14904.jpg (deflated 25%)
# ...

# %%
# !ls -la
# Out:
# total 25988
# drwxr-xr-x 3 root root     4096 Oct 15 21:58 .
# drwxr-xr-x 4 root root     4096 Oct 15 19:39 ..
# -rw-r--r-- 1 root root   768785 Oct 15 21:32 F1_curve.png
# -rw-r--r-- 1 root root   149384 Oct 15 21:32 PR_curve.png
# -rw-r--r-- 1 root root   693956 Oct 15 21:32 P_curve.png
# -rw-r--r-- 1 root root   621979 Oct 15 21:32 R_curve.png
# -rw-r--r-- 1 root root     1453 Oct 15 19:39 args.yaml
# -rw-r--r-- 1 root root   200712 Oct 15 21:32 confusion_matrix.png
# -rw-r--r-- 1 root root   205481 Oct 15 21:32 confusion_matrix_normalized.png
# -rw-r--r-- 1 root root  2779784 Oct 15 21:32 events.out.tfevents.1729021162.7fdea52af827.154.0
# -rw-r--r-- 1 root root   201859 Oct 15 19:41 labels.jpg
# -rw-r--r-- 1 root root   255753 Oct 15 19:41 labels_correlogram.jpg
# -rw-r--r-- 1 root root    21840 Oct 15 21:32 results.csv
# -rw-r--r-- 1 root root   264126 Oct 15 21:32 results.png
# -rw-r--r-- 1 root root 17387744 Oct 15 21:58 train2_results.zip
# ...

# %%
from IPython.display import FileLink

# Create a clickable link to download the file
FileLink(r'train2_results.zip')
# Out:
# /kaggle/runs/detect/train2/train2_results.zip

# %%
# !ls -la
# Out:
# total 25988
# drwxr-xr-x 3 root root     4096 Oct 15 21:58 .
# drwxr-xr-x 4 root root     4096 Oct 15 19:39 ..
# -rw-r--r-- 1 root root   768785 Oct 15 21:32 F1_curve.png
# -rw-r--r-- 1 root root   149384 Oct 15 21:32 PR_curve.png
# -rw-r--r-- 1 root root   693956 Oct 15 21:32 P_curve.png
# -rw-r--r-- 1 root root   621979 Oct 15 21:32 R_curve.png
# -rw-r--r-- 1 root root     1453 Oct 15 19:39 args.yaml
# -rw-r--r-- 1 root root   200712 Oct 15 21:32 confusion_matrix.png
# -rw-r--r-- 1 root root   205481 Oct 15 21:32 confusion_matrix_normalized.png
# -rw-r--r-- 1 root root  2779784 Oct 15 21:32 events.out.tfevents.1729021162.7fdea52af827.154.0
# -rw-r--r-- 1 root root   201859 Oct 15 19:41 labels.jpg
# -rw-r--r-- 1 root root   255753 Oct 15 19:41 labels_correlogram.jpg
# -rw-r--r-- 1 root root    21840 Oct 15 21:32 results.csv
# -rw-r--r-- 1 root root   264126 Oct 15 21:32 results.png
# -rw-r--r-- 1 root root 17387744 Oct 15 21:58 train2_results.zip
# ...

# %%
# !mv train2_results.zip /kaggle/working/

# %%
# !ls /kaggle/working/
# Out:
# train2_results.zip  ultralytics
